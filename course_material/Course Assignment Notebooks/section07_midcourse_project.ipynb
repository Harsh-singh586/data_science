# %% [markdown]
# # Mid-Course Project

# %% [markdown]
# Hi there,
#
# I’m the host of a movie reviews podcast and I’m currently making an episode about movie review aggregators.
#
# I found this data set from Rotten Tomatoes (inside the .ipynb file that I’ve attached). Could you dig into the data and share any interesting insights that you find? My audience loves fun facts about movies.
#
# Thank you!\
# KP

# %% [markdown]
# ## 0. Read in the Data

# %%
# rotten tomatoes movie data set from Maven's data playground
import pandas as pd

movies = pd.read_csv('../Data/Rotten Tomatoes Movies.csv')
movies.head(3)
# Out:
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
#
#                                    critics_consensus rating  \
# 0  Though it may seem like just another Harry Pot...     PG
# 1  Nicole Holofcener's newest might seem slight i...      R
# 2                                                NaN      R
#
#                                                genre          directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...     Chris Columbus
# 1                                             Comedy  Nicole Holofcener
# 2                                    Comedy, Romance      Blake Edwards
#
#              writers                                               cast  \
# 0       Craig Titley  Logan Lerman, Brandon T. Jackson, Alexandra Da...
# 1  Nicole Holofcener  Catherine Keener, Amanda Peet, Oliver Platt, R...
# 2      Blake Edwards  Dudley Moore, Bo Derek, Julie Andrews, Robert ...
#
#   in_theaters_date on_streaming_date  runtime_in_minutes  \
# 0       2010-02-12        2010-06-29                83.0
# 1       2010-04-30        2010-10-19                90.0
# 2       1979-10-05        1997-08-27               118.0
#
#               studio_name tomatometer_status  tomatometer_rating  \
# 0        20th Century Fox             Rotten                  49
# 1  Sony Pictures Classics    Certified Fresh                  86
# 2             Waner Bros.              Fresh                  68
#
#    tomatometer_count  audience_rating  audience_count
# 0                144             53.0        254287.0
# 1                140             64.0         11567.0
# 2                 22             53.0         14670.0

# %%
# let's work with a subset of the data for this project
movies = movies[['movie_title', 'rating', 'genre', 'in_theaters_date','runtime_in_minutes',
                 'tomatometer_rating', 'tomatometer_count', 'audience_rating', 'audience_count']]
movies.head()
# Out:
#                                          movie_title rating  \
# 0  Percy Jackson & the Olympians: The Lightning T...     PG
# 1                                        Please Give      R
# 2                                                 10      R
# 3                    12 Angry Men (Twelve Angry Men)     NR
# 4                       20,000 Leagues Under The Sea      G
#
#                                                genre in_theaters_date  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 1                                             Comedy       2010-04-30
# 2                                    Comedy, Romance       1979-10-05
# 3                                    Classics, Drama       1957-04-13
# 4           Action & Adventure, Drama, Kids & Family       1954-01-01
#
#    runtime_in_minutes  tomatometer_rating  tomatometer_count  audience_rating  \
# 0                83.0                  49                144             53.0
# 1                90.0                  86                140             64.0
# 2               118.0                  68                 22             53.0
# 3                95.0                 100                 51             97.0
# 4               127.0                  89                 27             74.0
#
#    audience_count
# 0        254287.0
# 1         11567.0
# 2         14670.0
# 3        105000.0
# 4         68860.0

# %% [markdown]
# ## 1. Explore the Data

# %% [markdown]
# How many movies are in this data set?

# %%
movies.shape
# Out:
# (16638, 9)

# %% [markdown]
# Filter the data to only include movies that came out in 2010 or later. How many movies are in this new data set?

# %%
movies.dtypes
# Out:
# movie_title                   object
# rating                        object
# genre                         object
# in_theaters_date      datetime64[ns]
# runtime_in_minutes           float64
# tomatometer_rating             int64
# tomatometer_count              int64
# audience_rating              float64
# audience_count               float64
# dtype: object

# %%
movies.in_theaters_date = pd.to_datetime(movies.in_theaters_date)

# %%
movie_2010 = movies[movies.in_theaters_date > pd.to_datetime("01-01-2010")]

# %% [markdown]
# Find the highest rated movies according to both critics (*tomatometer_rating*) and the general audience (*audience_rating*).

# %%
movie_2010.sort_values(["tomatometer_rating", "audience_rating"], ascending=False)
# Out:
#               movie_title rating                                     genre  \
# 4239           Charm City     NR                               Documentary
# 14566   The Miners' Hymns     NR      Documentary, Drama, Special Interest
# 15001     The Uncondemned     NR                               Documentary
# 9424               Maktub     NR  Art House & International, Comedy, Drama
# 1960                   5B  PG-13                               Documentary
# ...                   ...    ...                                       ...
# 7010      Hallowed Ground     NR                                    Horror
# 9636       Maximum Impact     NR                Action & Adventure, Comedy
# 11300             Portals     NR                                    Horror
# 13867   The Child Remains     NR                                    Horror
# 14134  The Gallows Act II      R                                    Horror
#
#       in_theaters_date  runtime_in_minutes  tomatometer_rating  \
# 4239        2018-10-19               108.0                 100
# 14566       2012-02-08                52.0                 100
# 15001       2016-10-21                81.0                 100
# 9424        2018-06-15               100.0                 100
# 1960        2019-06-14                93.0                 100
# ...                ...                 ...                 ...
# 7010        2019-06-07               117.0                   0
# 9636        2018-09-28               110.0                   0
# 11300       2019-10-25                80.0                   0
# 13867       2019-06-07               112.0                   0
# 14134       2019-10-25                99.0                   0
#
#        tomatometer_count  audience_rating  audience_count
# 4239                  16            100.0            24.0
# 14566                 10            100.0           148.0
# 15001                 13            100.0           124.0
# 9424                   5             99.0           396.0
# 1960                  17             97.0            35.0
# ...                  ...              ...             ...
# 7010                   6              NaN             NaN
# 9636                  10              NaN             NaN
# 11300                 10              NaN             NaN
# 13867                  6              NaN             NaN
# 14134                 10              NaN             NaN
#
# [6050 rows x 9 columns]

# %% [markdown]
# These top movies seem to have very few critics and audience members writing the reviews. We want to look at only the most popular movies. Filter the movies data set to only include movies that have 100k+ audience ratings. How many movies are in this data set?

# %%
movie_2010.describe()
# Out:
#        runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# count         5927.000000         6050.000000        6050.000000
# mean           101.009954           60.039008          74.744463
# std             17.203583           28.328759          82.868012
# min             15.000000            0.000000           5.000000
# 25%             90.000000           38.000000          15.000000
# 50%             98.000000           66.000000          38.000000
# 75%            110.000000           85.000000         112.000000
# max            333.000000          100.000000         497.000000
#
#        audience_rating  audience_count
# count      5953.000000    5.953000e+03
# mean         57.326726    1.999940e+04
# std          20.240969    6.486022e+04
# min           0.000000    5.000000e+00
# 25%          42.000000    3.440000e+02
# 50%          58.000000    1.719000e+03
# 75%          74.000000    1.129000e+04
# max         100.000000    2.373625e+06

# %%
movie_2010_aud_count = movie_2010[movie_2010.audience_count > 100000]

# %% [markdown]
# Find the highest rated **popular** movies according to both critics (*tomatometer_rating*) and the general audience (*audience_rating*).

# %%
movie_2010_aud_count.sort_values(["tomatometer_rating", "audience_rating"], ascending=False)
# Out:
#                              movie_title rating  \
# 7558            How to Train Your Dragon     PG
# 7925                          Inside Out     PG
# 15416                        Toy Story 3      G
# 16634                           Zootopia     PG
# 9355                  Mad Max: Fury Road      R
# ...                                  ...    ...
# 5945                      Fantastic Four  PG-13
# 6942                         Grown Ups 2  PG-13
# 3387   Big Mommas: Like Father, Like Son  PG-13
# 8714                  The Last Airbender     PG
# 12198                      Scary Movie 5  PG-13
#
#                                                    genre in_theaters_date  \
# 7558   Animation, Kids & Family, Science Fiction & Fa...       2010-03-26
# 7925                            Animation, Kids & Family       2015-06-19
# 15416                   Animation, Comedy, Kids & Family       2010-06-18
# 16634              Action & Adventure, Animation, Comedy       2016-03-04
# 9355       Action & Adventure, Science Fiction & Fantasy       2015-05-15
# ...                                                  ...              ...
# 5945                                  Action & Adventure       2015-08-07
# 6942                                              Comedy       2013-07-12
# 3387                                              Comedy       2011-02-18
# 8714   Action & Adventure, Kids & Family, Science Fic...       2010-07-01
# 12198                 Comedy, Horror, Mystery & Suspense       2013-04-12
#
#        runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 7558                 98.0                  99                208
# 7925                 94.0                  98                357
# 15416               103.0                  98                305
# 16634               108.0                  97                279
# 9355                120.0                  97                410
# ...                   ...                 ...                ...
# 5945                100.0                   9                252
# 6942                101.0                   7                112
# 3387                107.0                   5                 60
# 8714                103.0                   5                189
# 12198                86.0                   4                 51
#
#        audience_rating  audience_count
# 7558              91.0        312342.0
# 7925              89.0        136125.0
# 15416             89.0        606931.0
# 16634             92.0        100946.0
# 9355              85.0        127428.0
# ...                ...             ...
# 5945              18.0        137562.0
# 6942              53.0        180859.0
# 3387              58.0        132093.0
# 8714              30.0        321915.0
# 12198             38.0        236153.0
#
# [316 rows x 9 columns]

# %% [markdown]
# A lot of these popular movies seem to have a PG or PG-13 rating. How many movies fall under each type of rating?
#
# *Use this popular movies data set going forward in this notebook.*

# %%
movie_2010_aud_count.rating.value_counts().reset_index()
# Out:
#    index  rating
# 0  PG-13     160
# 1      R     100
# 2     PG      51
# 3      G       5

# %%
mask = (movie_2010_aud_count.rating == "PG-13") | (movie_2010_aud_count.rating == "PG")

# %%
movie_2010_aud_count.loc[mask]
# Out:
#                                              movie_title rating  \
# 0      Percy Jackson & the Olympians: The Lightning T...     PG
# 248                                          Tron Legacy     PG
# 265                                        The Last Song     PG
# 1657                                             RoboCop  PG-13
# 1664                                     The Tooth Fairy     PG
# ...                                                  ...    ...
# 16472                                     Wreck-it Ralph     PG
# 16491                                  X-Men: Apocalypse  PG-13
# 16492                         X-Men: Days of Future Past  PG-13
# 16493                                 X-Men: First Class  PG-13
# 16634                                           Zootopia     PG
#
#                                                    genre in_theaters_date  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 248        Action & Adventure, Science Fiction & Fantasy       2010-12-17
# 265                        Drama, Kids & Family, Romance       2010-03-31
# 1657       Action & Adventure, Science Fiction & Fantasy       2014-02-12
# 1664    Comedy, Kids & Family, Science Fiction & Fantasy       2010-01-22
# ...                                                  ...              ...
# 16472                   Animation, Comedy, Kids & Family       2012-11-02
# 16491      Action & Adventure, Science Fiction & Fantasy       2016-05-27
# 16492      Action & Adventure, Science Fiction & Fantasy       2014-05-23
# 16493  Action & Adventure, Drama, Science Fiction & F...       2011-06-03
# 16634              Action & Adventure, Animation, Comedy       2016-03-04
#
#        runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 0                    83.0                  49                144
# 248                 125.0                  51                239
# 265                 107.0                  20                118
# 1657                117.0                  49                211
# 1664                101.0                  18                114
# ...                   ...                 ...                ...
# 16472                92.0                  87                184
# 16491               136.0                  47                333
# 16492               131.0                  90                318
# 16493               132.0                  86                290
# 16634               108.0                  97                279
#
#        audience_rating  audience_count
# 0                 53.0        254287.0
# 248               63.0        171385.0
# 265               66.0        160777.0
# 1657              49.0        127081.0
# 1664              41.0        183707.0
# ...                ...             ...
# 16472             86.0        238763.0
# 16491             65.0        127400.0
# 16492             91.0        276699.0
# 16493             87.0        184330.0
# 16634             92.0        100946.0
#
# [211 rows x 9 columns]

# %% [markdown]
# What is the average audience rating for each movie rating type? Which rating type is most highly rated?

# %%
movie_2010_aud_count.groupby("rating")["audience_rating"].mean().reset_index()
# Out:
#   rating  audience_rating
# 0      G        66.200000
# 1     PG        66.823529
# 2  PG-13        67.293750
# 3      R        63.010000

# %% [markdown]
# ## 2. Create New Columns

# %% [markdown]
# Create a column in the DataFrame called 'Animation' and return a 1 if a movie is an 'Animation' movie and 0 otherwise. Do the same for *Action & Adventure* and *Comedy*.
#
# *Hint: use np.where and str.contains*

# %%
import numpy as np

# %%
movie_2010_aud_count["Animation"] = np.where(movie_2010_aud_count.genre.str.contains("Animation"), 1, 0)
# Out:
# C:\Users\harshs\AppData\Local\Temp\ipykernel_28460\1997711081.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_2010_aud_count["Animation"] = np.where(movie_2010_aud_count.genre.str.contains("Animation"), 1, 0)

# %%
movie_2010_aud_count[movie_2010_aud_count.Animation == 1].head()
# Out:
#                               movie_title rating  \
# 1766                        Despicable Me     PG
# 3381                           Big Hero 6     PG
# 3771                                Brave     PG
# 4119                               Cars 2      G
# 4474  Cloudy with a Chance of Meatballs 2     PG
#
#                                                   genre in_theaters_date  \
# 1766                   Animation, Comedy, Kids & Family       2010-07-09
# 3381                           Animation, Kids & Family       2014-11-07
# 3771                   Animation, Comedy, Kids & Family       2012-06-22
# 4119  Action & Adventure, Animation, Comedy, Kids & ...       2011-06-24
# 4474  Action & Adventure, Animation, Kids & Family, ...       2013-09-27
#
#       runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 1766                95.0                  81                197
# 3381                93.0                  89                219
# 3771                93.0                  78                243
# 4119               112.0                  39                215
# 4474                95.0                  71                120
#
#       audience_rating  audience_count  Animation
# 1766             82.0        267208.0          1
# 3381             91.0        129162.0          1
# 3771             76.0        279048.0          1
# 4119             49.0        103439.0          1
# 4474             66.0        123841.0          1

# %%
movie_2010_aud_count["Action & Adventure"] = np.where(movie_2010_aud_count.genre.str.contains("Action & Adventure"), 1, 0)
# Out:
# C:\Users\harshs\AppData\Local\Temp\ipykernel_28460\2746254148.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_2010_aud_count["Action & Adventure"] = np.where(movie_2010_aud_count.genre.str.contains("Action & Adventure"), 1, 0)

# %%
movie_2010_aud_count["Comedy"] = np.where(movie_2010_aud_count.genre.str.contains("Comedy"), 1, 0)
# Out:
# C:\Users\harshs\AppData\Local\Temp\ipykernel_28460\2692013293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_2010_aud_count["Comedy"] = np.where(movie_2010_aud_count.genre.str.contains("Comedy"), 1, 0)

# %%
movie_2010_aud_count.head()
# Out:
#                                            movie_title rating  \
# 0    Percy Jackson & the Olympians: The Lightning T...     PG
# 248                                        Tron Legacy     PG
# 265                                      The Last Song     PG
# 274                                           Repo Men      R
# 284                                          Predators      R
#
#                                                  genre in_theaters_date  \
# 0    Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 248      Action & Adventure, Science Fiction & Fantasy       2010-12-17
# 265                      Drama, Kids & Family, Romance       2010-03-31
# 274      Action & Adventure, Science Fiction & Fantasy       2010-03-19
# 284  Action & Adventure, Horror, Science Fiction & ...       2010-07-09
#
#      runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 0                  83.0                  49                144
# 248               125.0                  51                239
# 265               107.0                  20                118
# 274               119.0                  22                151
# 284               107.0                  65                198
#
#      audience_rating  audience_count  Animation  Action & Adventure  Comedy
# 0               53.0        254287.0          0                   1       1
# 248             63.0        171385.0          0                   1       0
# 265             66.0        160777.0          0                   0       0
# 274             41.0        100453.0          0                   1       0
# 284             52.0        159760.0          0                   1       0

# %% [markdown]
# Create a table where each row is a rating, each column is a genre and each value is the number of movies of that particular rating and genre. What insights do you gather?

# %%
movie_2010_aud_count.groupby("rating")["Animation", "Action & Adventure", "Comedy"].sum()
# Out:
# C:\Users\harshs\AppData\Local\Temp\ipykernel_28460\1546975807.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   movie_2010_aud_count.groupby("rating")["Animation", "Action & Adventure", "Comedy"].sum()
#         Animation  Action & Adventure  Comedy
# rating
# G               5                   3       5
# PG             26                  27      29
# PG-13           0                 102      35
# R               0                  41      35

# %% [markdown]
# Find the average critic and audience rating for an Animation movie vs a non-Animation movie. Do the same for Action & Adventure and Comedy. What insights do you gather?

# %%
movie_2010_aud_count.groupby("Animation")[["tomatometer_rating", "audience_rating"]].mean()
# Out:
#            tomatometer_rating  audience_rating
# Animation
# 0                   58.340351        64.831579
# 1                   75.258065        75.161290

# %%
movie_2010_aud_count.groupby("Action & Adventure")[["tomatometer_rating", "audience_rating"]].mean()
# Out:
#                     tomatometer_rating  audience_rating
# Action & Adventure
# 0                            59.111888        65.391608
# 1                            60.734104        66.219653

# %%
movie_2010_aud_count.groupby("Comedy")[["tomatometer_rating", "audience_rating"]].mean()
# Out:
#         tomatometer_rating  audience_rating
# Comedy
# 0                62.169811        67.353774
# 1                55.576923        62.769231

# %% [markdown]
# ## 3. Visualize the Data

# %% [markdown]
# Create a pair plot from the popular movies DataFrame.

# %%
import seaborn as sns

# %%
sns.pairplot(movie_2010_aud_count.iloc[:, :-3])

# %% [markdown]
# What insights can you gather from this pair plot?
# * How do the critic ratings (tomatometer_rating) compare with the audience ratings (compare the histograms)?
# * What are some surprising findings about the run times of movies compared with other fields (look at the scatter plots)?
# * What is the most popular movie by far in terms of the number of audience ratings?
