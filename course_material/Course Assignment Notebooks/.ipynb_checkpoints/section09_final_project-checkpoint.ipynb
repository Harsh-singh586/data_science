# %% [markdown]
# # Final Project

# %% [markdown]
# ## 1. Scope the Project

# %% [markdown]
# Our plan is to use a supervised learning technique to predict which customers are most likely to cancel their subscription using **the past three months of customer data which includes subscription and listening history**.

# %% [markdown]
# ## 2. Gather Data

# %% [markdown]
# Read the following files into Python:
# * Customer data: *maven_music_customers.csv*
# * Listing history: *maven_music_listening_history.xlsx*

# %%
import pandas as pd

# %%
# Read in the customer data
customers = pd.read_csv('../Data/maven_music_customers.csv')

# %%
# Read in the listening history
listening_hist = pd.read_excel('../Data/maven_music_listening_history.xlsx')

# %%
# Hint: Where might you find listening history data beyond the ID's?

# %%
# Read in the audio data
audio = pd.read_excel('../Data/maven_music_listening_history.xlsx', sheet_name=1)

# %%
# Read in the session data
session = pd.read_excel('../Data/maven_music_listening_history.xlsx', sheet_name=2)

# %%
customers.head()
# Out:
#    Customer ID   Customer Name                              Email  \
# 0         5001  Harmony Greene  Email: harmonious.vibes@email.com
# 1         5002       Aria Keys    Email: melodious.aria@email.edu
# 2         5004      Lyric Bell  Email: rhythmical.lyric@email.com
# 3         5267    Rock Bassett       Email: groovy.rock@email.com
# 4         5338    Rhythm Dixon   Email: beats.by.rhythm@email.edu
#
#   Member Since Subscription Plan Subscription Rate Discount? Cancellation Date
# 0      3/13/23       Basic (Ads)            $2.99        NaN               NaN
# 1      3/13/23               NaN            $2.99        NaN               NaN
# 2      3/13/23               NaN            $2.99        NaN            6/1/23
# 3      3/20/23       Basic (Ads)            $2.99        NaN               NaN
# 4      3/20/23               NaN            $2.99        NaN               NaN

# %%
listening_hist.head()
# Out:
#    Customer ID  Session ID  Audio Order  Audio ID Audio Type
# 0         5001      100520            1       101       Song
# 1         5001      100520            2       102       Song
# 2         5001      100520            3       103       Song
# 3         5001      100520            4       104       Song
# 4         5001      100520            5       105       Song

# %%
audio.head()
# Out:
#          ID              Name      Genre  Popularity
# 0  Song-101   Dance All Night        Pop           1
# 1  Song-102  Unbreakable Beat        Pop           2
# 2  Song-103  Sunset Boulevard  Pop Music           5
# 3  Song-104    Glowing Hearts  Pop Music          10
# 4  Song-105         Pop Rocks  Pop Music          52

# %%
session.head()
# Out:
#    Session ID Session Log In Time
# 0      100520 2023-03-13 18:29:00
# 1      100522 2023-03-13 22:15:00
# 2      100525 2023-03-14 10:01:00
# 3      100527 2023-03-13 14:14:00
# 4      100538 2023-03-21 12:23:00

# %% [markdown]
# ## 3. Clean Data

# %% [markdown]
# ### a. Convert Data Types

# %% [markdown]
# Check the data types of the data in the tables and convert to numeric and datetime values as necessary.

# %%
# Check the data types
# check data type of customer
customers.dtypes
# Out:
# Customer ID           int64
# Customer Name        object
# Email                object
# Member Since         object
# Subscription Plan    object
# Subscription Rate    object
# Discount?            object
# Cancellation Date    object
# dtype: object

# %%
#member since -- datetime, subscription rate -- numeric, discount -- numeric, cancellation date -- dateeime
customers["Member Since"] = pd.to_datetime(customers["Member Since"])
customers["Subscription Rate"] = pd.to_numeric(customers["Subscription Rate"].str.replace("$", ""))
customers["Cancellation Date"] = pd.to_datetime(customers["Cancellation Date"])
# Out:
# C:\Users\harshs\AppData\Local\Temp\ipykernel_64728\2448803970.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   customers["Subscription Rate"] = pd.to_numeric(customers["Subscription Rate"].str.replace("$", ""))

# %%
listening_hist.dtypes
# Out:
# Customer ID     int64
# Session ID      int64
# Audio Order     int64
# Audio ID        int64
# Audio Type     object
# dtype: object

# %%
audio.dtypes
# Out:
# ID            object
# Name          object
# Genre         object
# Popularity     int64
# dtype: object

# %% [markdown]
# ### b. Resolve Data Issues

# %% [markdown]
# Check for missing data, inconsistent text and typos, duplicate data and outliers.

# %% [markdown]
# #### i. Missing Data

# %%
# Look for NaN values in the data
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer ID        30 non-null     int64
#  1   Customer Name      30 non-null     object
#  2   Email              30 non-null     object
#  3   Member Since       30 non-null     datetime64[ns]
#  4   Subscription Plan  25 non-null     object
#  5   Subscription Rate  30 non-null     float64
#  6   Discount?          7 non-null      object
#  7   Cancellation Date  13 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 2.0+ KB

# %%
# subscription plan -- 5 null, discount -- 23 null, cancellation date -- 17 null

# %%
customers['Subscription Plan'].value_counts(dropna = False)
# Out:
# Premium (No Ads)    13
# Basic (Ads)         12
# NaN                  5
# Name: Subscription Plan, dtype: int64

# %%
customers[customers['Subscription Plan'].isna()]
# Out:
#     Customer ID    Customer Name                               Email  \
# 1          5002        Aria Keys     Email: melodious.aria@email.edu
# 2          5004       Lyric Bell   Email: rhythmical.lyric@email.com
# 4          5338     Rhythm Dixon    Email: beats.by.rhythm@email.edu
# 5          5404      Jazz Saxton          Email: jazzy.sax@email.com
# 11         5827  Rhythm Franklin  Email: rhythmic.franklin@email.edu
#
#    Member Since Subscription Plan  Subscription Rate Discount?  \
# 1    2023-03-13               NaN               2.99       NaN
# 2    2023-03-13               NaN               2.99       NaN
# 4    2023-03-20               NaN               2.99       NaN
# 5    2023-03-20               NaN               2.99       NaN
# 11   2023-03-28               NaN               2.99       NaN
#
#    Cancellation Date
# 1                NaT
# 2         2023-06-01
# 4                NaT
# 5         2023-06-03
# 11               NaT

# %%
# subscription Plan should be dependent on subscription rate, since all NaN has rate of 2.99 we can impute value of corresponding plan
# check plan for rate of 2.99
customers[customers['Subscription Rate'] == 2.99]
# Out:
#     Customer ID    Customer Name                                Email  \
# 0          5001   Harmony Greene    Email: harmonious.vibes@email.com
# 1          5002        Aria Keys      Email: melodious.aria@email.edu
# 2          5004       Lyric Bell    Email: rhythmical.lyric@email.com
# 3          5267     Rock Bassett         Email: groovy.rock@email.com
# 4          5338     Rhythm Dixon     Email: beats.by.rhythm@email.edu
# 5          5404      Jazz Saxton           Email: jazzy.sax@email.com
# 9          5763     Jazz Coleman  Email: coleman.jazzmaster@email.com
# 10         5826      Chord Hayes      Email: harmonic.chord@email.com
# 11         5827  Rhythm Franklin   Email: rhythmic.franklin@email.edu
# 13         6092       Benny Beat      Email: rhythmic.benny@email.com
# 16         6406   Beatrice Sharp   Email: beats.by.beatrice@email.com
# 17         6584       Bobby Bass   Email: bass.master.bobby@email.edu
# 18         6586   Lyric Saunders    Email: lyrical.saunders@email.edu
# 19         6588     Harmony Bass        Email: bass.harmony@email.com
# 20         6821        Reed Flat          Email: flat.tunes@email.edu
# 24         7158  Harmony Wallace     Email: wallace.harmony@email.com
# 27         7579    Jazz Drummond       Email: drumming.jazz@email.com
#
#    Member Since Subscription Plan  Subscription Rate Discount?  \
# 0    2023-03-13       Basic (Ads)               2.99       NaN
# 1    2023-03-13               NaN               2.99       NaN
# 2    2023-03-13               NaN               2.99       NaN
# 3    2023-03-20       Basic (Ads)               2.99       NaN
# 4    2023-03-20               NaN               2.99       NaN
# 5    2023-03-20               NaN               2.99       NaN
# 9    2023-03-28       Basic (Ads)               2.99       NaN
# 10   2023-03-28       Basic (Ads)               2.99       NaN
# 11   2023-03-28               NaN               2.99       NaN
# 13   2023-04-01       Basic (Ads)               2.99       NaN
# 16   2023-04-08       Basic (Ads)               2.99       NaN
# 17   2023-04-09       Basic (Ads)               2.99       NaN
# 18   2023-04-16       Basic (Ads)               2.99       NaN
# 19   2023-04-16       Basic (Ads)               2.99       NaN
# 20   2023-04-24       Basic (Ads)               2.99       NaN
# 24   2023-05-07       Basic (Ads)               2.99       NaN
# 27   2023-05-15       Basic (Ads)               2.99       NaN
#
#    Cancellation Date
# 0                NaT
# 1                NaT
# 2         2023-06-01
# 3                NaT
# 4                NaT
# 5         2023-06-03
# 9                NaT
# 10               NaT
# 11               NaT
# 13        2023-06-01
# 16               NaT
# 17               NaT
# 18               NaT
# 19        2023-06-01
# 20               NaT
# 24               NaT
# 27               NaT

# %%
# imputing Basic (ADS) in NaN
customers['Subscription Plan'] =  np.where(customers['Subscription Rate'] == 2.99 , "Basic (ADS)", customers['Subscription Plan'])

# %%
customers['Discount?'].value_counts()
# Out:
# Yes    7
# Name: Discount?, dtype: int64

# %%
# replacing nan with No
customers['Discount?'] = customers['Discount?'].fillna("No")

# %%
customers["Cancellation Date"].value_counts()
# Out:
# 2023-06-01    6
# 2023-06-02    5
# 2023-06-03    2
# Name: Cancellation Date, dtype: int64

# %%
listening_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Customer ID  505 non-null    int64
#  1   Session ID   505 non-null    int64
#  2   Audio Order  505 non-null    int64
#  3   Audio ID     505 non-null    int64
#  4   Audio Type   505 non-null    object
# dtypes: int64(4), object(1)
# memory usage: 19.9+ KB

# %%
audio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          17 non-null     object
#  1   Name        17 non-null     object
#  2   Genre       17 non-null     object
#  3   Popularity  17 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 676.0+ bytes

# %%
session.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Session ID           90 non-null     int64
#  1   Session Log In Time  90 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.5 KB

# %% [markdown]
# #### ii. Inconsistent Text & Typos

# %%
# Look for inconsistent text & typos
customers['Email'] = customers['Email'].str.replace("Email: ", "")

# %% [markdown]
# #### iii. Duplicate Rows

# %%
# Look for duplicate rows
customers[customers.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Customer Name, Email, Member Since, Subscription Plan, Subscription Rate, Discount?, Cancellation Date]
# Index: []

# %%
listening_hist[listening_hist.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Session ID, Audio Order, Audio ID, Audio Type]
# Index: []

# %%
session[session.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Session ID, Session Log In Time]
# Index: []

# %%
audio[audio.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Genre, Popularity]
# Index: []

# %% [markdown]
# #### iv. Outliers

# %%
# Look for outliers
import seaborn as sns

# %%
sns.pairplot(customers)

# %%
# can see a possible outlier in subscription rate
sns.boxplot(x = customers["Subscription Rate"])
# Out:
# <Axes: xlabel='Subscription Rate'>

# %%
mean = np.mean(customers["Subscription Rate"])
sd = np.std(customers["Subscription Rate"])
min_val = mean - 3 * sd
max_val = mean + 3 * sd
min_val, max_val
# Out:
# (-43.11353751330536, 60.226870846638704)

# %%
mask = (customers["Subscription Rate"] < min_val) | (customers["Subscription Rate"] > max_val)
customers[mask]
# Out:
#     Customer ID    Customer Name                      Email Member Since  \
# 15         6229  Symphony Rhodes  rhodes.symphony@email.com   2023-04-06
#
#    Subscription Plan  Subscription Rate Discount? Cancellation Date
# 15  Premium (No Ads)              99.99        No        2023-06-02

# %%
# cplan and rate should be realted so looking rate for subscription plan of Premium (No Ads)
customers[customers["Subscription Plan"] == "Premium (No Ads)"]
# Out:
#     Customer ID      Customer Name                        Email Member Since  \
# 6          5581         Reed Sharp        sharp.tunes@email.com   2023-03-21
# 7          5759     Carol Kingbird     songbird.carol@email.com   2023-03-22
# 8          5761        Sonata Nash     musical.sonata@email.com   2023-03-28
# 12         6029     Chord Campbell  campbell.chordify@email.com   2023-03-29
# 14         6163       Melody Parks   park.of.melodies@email.com   2023-04-05
# 15         6229    Symphony Rhodes    rhodes.symphony@email.com   2023-04-06
# 21         6822          Kiki Keys    kiki.keys.piano@email.com   2023-05-01
# 22         6824       Greta Groove       groovy.greta@email.com   2023-05-01
# 23         7087      Harmony Heart  heartfelt.harmony@email.com   2023-05-01
# 25         7224  Melody Fitzgerald  fitzgerald.melody@email.com   2023-05-08
# 26         7401        Reed Murphy  murphy.reed.music@email.com   2023-05-08
# 28         7581         Lyric Keys        keysoflyric@email.com   2023-05-16
# 29         7583      Melody Singer     melodic.singer@email.com   2023-05-16
#
#    Subscription Plan  Subscription Rate Discount? Cancellation Date
# 6   Premium (No Ads)               9.99        No               NaT
# 7   Premium (No Ads)               9.99        No        2023-06-02
# 8   Premium (No Ads)               9.99        No               NaT
# 12  Premium (No Ads)               9.99        No        2023-06-02
# 14  Premium (No Ads)               9.99        No               NaT
# 15  Premium (No Ads)              99.99        No        2023-06-02
# 21  Premium (No Ads)               7.99       Yes               NaT
# 22  Premium (No Ads)               7.99       Yes        2023-06-02
# 23  Premium (No Ads)               7.99       Yes        2023-06-02
# 25  Premium (No Ads)               7.99       Yes        2023-06-01
# 26  Premium (No Ads)               7.99       Yes        2023-06-01
# 28  Premium (No Ads)               7.99       Yes        2023-06-03
# 29  Premium (No Ads)               7.99       Yes        2023-06-01

# %%
# rate for subscription plan Premium (No Ads) is 9.99 or 7.99 so manipulating the value
customers.iloc[15, 5] = 9.99

# %% [markdown]
# ### c. Create New Columns

# %% [markdown]
# Create two new columns that will be useful for EDA and modeling:
# * Cancelled: whether a customer cancelled or not
# * Email: Remove the "Email:" from the email addresses

# %%
# Create a 'Cancelled' column
customers["Cancelled"] = np.where(customers["Cancellation Date"].isna(), 0, 1)

# %%
customers
# Out:
#     Customer ID      Customer Name                         Email Member Since  \
# 0          5001     Harmony Greene    harmonious.vibes@email.com   2023-03-13
# 1          5002          Aria Keys      melodious.aria@email.edu   2023-03-13
# 2          5004         Lyric Bell    rhythmical.lyric@email.com   2023-03-13
# 3          5267       Rock Bassett         groovy.rock@email.com   2023-03-20
# 4          5338       Rhythm Dixon     beats.by.rhythm@email.edu   2023-03-20
# 5          5404        Jazz Saxton           jazzy.sax@email.com   2023-03-20
# 6          5581         Reed Sharp         sharp.tunes@email.com   2023-03-21
# 7          5759     Carol Kingbird      songbird.carol@email.com   2023-03-22
# 8          5761        Sonata Nash      musical.sonata@email.com   2023-03-28
# 9          5763       Jazz Coleman  coleman.jazzmaster@email.com   2023-03-28
# 10         5826        Chord Hayes      harmonic.chord@email.com   2023-03-28
# 11         5827    Rhythm Franklin   rhythmic.franklin@email.edu   2023-03-28
# 12         6029     Chord Campbell   campbell.chordify@email.com   2023-03-29
# 13         6092         Benny Beat      rhythmic.benny@email.com   2023-04-01
# 14         6163       Melody Parks    park.of.melodies@email.com   2023-04-05
# 15         6229    Symphony Rhodes     rhodes.symphony@email.com   2023-04-06
# 16         6406     Beatrice Sharp   beats.by.beatrice@email.com   2023-04-08
# 17         6584         Bobby Bass   bass.master.bobby@email.edu   2023-04-09
# 18         6586     Lyric Saunders    lyrical.saunders@email.edu   2023-04-16
# 19         6588       Harmony Bass        bass.harmony@email.com   2023-04-16
# 20         6821          Reed Flat          flat.tunes@email.edu   2023-04-24
# 21         6822          Kiki Keys     kiki.keys.piano@email.com   2023-05-01
# 22         6824       Greta Groove        groovy.greta@email.com   2023-05-01
# 23         7087      Harmony Heart   heartfelt.harmony@email.com   2023-05-01
# 24         7158    Harmony Wallace     wallace.harmony@email.com   2023-05-07
# 25         7224  Melody Fitzgerald   fitzgerald.melody@email.com   2023-05-08
# 26         7401        Reed Murphy   murphy.reed.music@email.com   2023-05-08
# 27         7579      Jazz Drummond       drumming.jazz@email.com   2023-05-15
# 28         7581         Lyric Keys         keysoflyric@email.com   2023-05-16
# 29         7583      Melody Singer      melodic.singer@email.com   2023-05-16
#
#    Subscription Plan  Subscription Rate Discount? Cancellation Date  Cancelled
# 0        Basic (ADS)               2.99        No               NaT          0
# 1        Basic (ADS)               2.99        No               NaT          0
# 2        Basic (ADS)               2.99        No        2023-06-01          1
# 3        Basic (ADS)               2.99        No               NaT          0
# 4        Basic (ADS)               2.99        No               NaT          0
# 5        Basic (ADS)               2.99        No        2023-06-03          1
# 6   Premium (No Ads)               9.99        No               NaT          0
# 7   Premium (No Ads)               9.99        No        2023-06-02          1
# 8   Premium (No Ads)               9.99        No               NaT          0
# 9        Basic (ADS)               2.99        No               NaT          0
# 10       Basic (ADS)               2.99        No               NaT          0
# 11       Basic (ADS)               2.99        No               NaT          0
# 12  Premium (No Ads)               9.99        No        2023-06-02          1
# 13       Basic (ADS)               2.99        No        2023-06-01          1
# 14  Premium (No Ads)               9.99        No               NaT          0
# 15  Premium (No Ads)               9.99        No        2023-06-02          1
# 16       Basic (ADS)               2.99        No               NaT          0
# 17       Basic (ADS)               2.99        No               NaT          0
# 18       Basic (ADS)               2.99        No               NaT          0
# 19       Basic (ADS)               2.99        No        2023-06-01          1
# 20       Basic (ADS)               2.99        No               NaT          0
# 21  Premium (No Ads)               7.99       Yes               NaT          0
# 22  Premium (No Ads)               7.99       Yes        2023-06-02          1
# 23  Premium (No Ads)               7.99       Yes        2023-06-02          1
# 24       Basic (ADS)               2.99        No               NaT          0
# 25  Premium (No Ads)               7.99       Yes        2023-06-01          1
# 26  Premium (No Ads)               7.99       Yes        2023-06-01          1
# 27       Basic (ADS)               2.99        No               NaT          0
# 28  Premium (No Ads)               7.99       Yes        2023-06-03          1
# 29  Premium (No Ads)               7.99       Yes        2023-06-01          1

# %%
# Create an updated 'Email' column without the Email: portion

# %% [markdown]
# ## 4. EDA

# %% [markdown]
# Try to better understand the customers who cancelled:
# * How long were they members before they cancelled?
# * What percentage of customers who cancelled had a discount vs customers who didn't cancel?

# %%
# How long were customers members before they cancelled?
customers_cancelled = customers[customers["Cancelled"] == 1]
customers_cancelled_days = (customers_cancelled["Cancellation Date"] - customers_cancelled["Member Since"]).dt.days.rename("Memership Days")
print("Average Membership days of cancelled member", customers_cancelled_days.mean())
# Out:
# Average Membership days of cancelled member 46.30769230769231

# %%
customers_cancelled_days
# Out:
# 2     80
# 5     75
# 7     72
# 12    65
# 13    61
# 15    57
# 19    46
# 22    32
# 23    32
# 25    24
# 26    24
# 28    18
# 29    16
# Name: Memership Days, dtype: int64

# %%
customers.groupby("Cancelled")['Customer ID'].count().plot.bar()
# Out:
# <Axes: xlabel='Cancelled'>

# %%
# 
customers_cancelled.groupby("Discount?")['Customer ID'].count()
# Out:
# Discount?
# No     7
# Yes    6
# Name: Customer ID, dtype: int64

# %%
# Cancellation rate for those who had a discount
customers_cancelled.groupby("Discount?")['Customer ID'].count().plot.bar()
# Out:
# <Axes: xlabel='Discount?'>

# %%
# cancelled Count by subscription plan
customers_cancelled.groupby(["Subscription Plan"])["Customer ID"].count()
# Out:
# Subscription Plan
# Basic (ADS)         4
# Premium (No Ads)    9
# Name: Customer ID, dtype: int64

# %%
customers_cancelled.groupby(["Subscription Plan"])["Customer ID"].count().plot.bar()
# Out:
# <Axes: xlabel='Subscription Plan'>

# %%
customers.groupby("Subscription Plan")["Customer ID"].count()
# Out:
# Subscription Plan
# Basic (ADS)         17
# Premium (No Ads)    13
# Name: Customer ID, dtype: int64

# %%
# number of customers joined in month
customers["Member Since"].dt.month.value_counts()
# Out:
# 3    13
# 5     9
# 4     8
# Name: Member Since, dtype: int64

# %%
# number of education staff customers
len(customers[customers["Email"].str.contains('edu')])
# Out:
# 6

# %% [markdown]
# Better understand the customers' listening histories:
# * Join together the listening history and audio tables
# * How many listening sessions did each customer have in the past 3 months?
# * What were the most popular genres that customers listened to?

# %%
customers.head()
# Out:
#    Customer ID   Customer Name                       Email Member Since  \
# 0         5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 1         5002       Aria Keys    melodious.aria@email.edu   2023-03-13
# 2         5004      Lyric Bell  rhythmical.lyric@email.com   2023-03-13
# 3         5267    Rock Bassett       groovy.rock@email.com   2023-03-20
# 4         5338    Rhythm Dixon   beats.by.rhythm@email.edu   2023-03-20
#
#   Subscription Plan  Subscription Rate Discount? Cancellation Date  Cancelled
# 0       Basic (ADS)               2.99        No               NaT          0
# 1       Basic (ADS)               2.99        No               NaT          0
# 2       Basic (ADS)               2.99        No        2023-06-01          1
# 3       Basic (ADS)               2.99        No               NaT          0
# 4       Basic (ADS)               2.99        No               NaT          0

# %%
audio.head()
# Out:
#          ID              Name      Genre  Popularity
# 0  Song-101   Dance All Night        Pop           1
# 1  Song-102  Unbreakable Beat        Pop           2
# 2  Song-103  Sunset Boulevard  Pop Music           5
# 3  Song-104    Glowing Hearts  Pop Music          10
# 4  Song-105         Pop Rocks  Pop Music          52

# %%
listening_hist.head()
# Out:
#    Customer ID  Session ID  Audio Order  Audio ID Audio Type
# 0         5001      100520            1       101       Song
# 1         5001      100520            2       102       Song
# 2         5001      100520            3       103       Song
# 3         5001      100520            4       104       Song
# 4         5001      100520            5       105       Song

# %%
session.head()
# Out:
#    Session ID Session Log In Time
# 0      100520 2023-03-13 18:29:00
# 1      100522 2023-03-13 22:15:00
# 2      100525 2023-03-14 10:01:00
# 3      100527 2023-03-13 14:14:00
# 4      100538 2023-03-21 12:23:00

# %%
# Split the ID in the audio data so the column can be joined with other tables
audio["ID"] = audio["ID"].str.replace("Song-", "")
audio["ID"] = audio["ID"].str.replace("Podcast-", "")

# %%
# Hint: Check the data type of Audio ID in the audio table
audio["ID"] = pd.to_numeric(audio["ID"])

# %%
# The number of listening sessions that each customer had in the past 3 months
listening_hist.groupby("Customer ID")["Audio Order"].count()
# Out:
# Customer ID
# 5001    60
# 5002    22
# 5004     9
# 5267    45
# 5338    18
# 5404     8
# 5581     5
# 5759    15
# 5761     5
# 5763    31
# 5826    17
# 5827     7
# 6029    12
# 6092    10
# 6163     4
# 6229    13
# 6406     9
# 6584    27
# 6586    22
# 6588    10
# 6821    21
# 6822    15
# 6824    31
# 7087    11
# 7158    13
# 7224    29
# 7401    11
# 7579     9
# 7581    14
# 7583     2
# Name: Audio Order, dtype: int64

# %%
# The most popular genres that customers listened to
audio[audio["Popularity"] == audio["Popularity"].max()]
# Out:
#      ID            Name Genre  Popularity
# 11  112  Midnight Blues  Jazz          80

# %%
listening_hist["Audio Type"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
audio_listening_hist = listening_hist.merge(audio, how="left", left_on="Audio ID", right_on="ID")
audio_listening_hist.head()
# Out:
#    Customer ID  Session ID  Audio Order  Audio ID Audio Type   ID  \
# 0         5001      100520            1       101       Song  101
# 1         5001      100520            2       102       Song  102
# 2         5001      100520            3       103       Song  103
# 3         5001      100520            4       104       Song  104
# 4         5001      100520            5       105       Song  105
#
#                Name      Genre  Popularity
# 0   Dance All Night        Pop           1
# 1  Unbreakable Beat        Pop           2
# 2  Sunset Boulevard  Pop Music           5
# 3    Glowing Hearts  Pop Music          10
# 4         Pop Rocks  Pop Music          52

# %%
# how many time each audio type was listened
audio_listening_hist.groupby("Audio Type").size()
# Out:
# Audio Type
# Podcast     42
# Song       463
# dtype: int64

# %%
# how many time each genre was listened
audio_listening_hist.groupby("Genre").size()
# Out:
# Genre
# Comedy         19
# Country        68
# Hip Hop        88
# Jazz           48
# Pop           100
# Pop Music     167
# True Crime     15
# dtype: int64

# %% [markdown]
# ## 5. Prep for Modeling

# %% [markdown]
# Create a DataFrame that is ready for modeling with each row representing a customer and the following numeric, non-null columns:
# * Customer ID
# * Whether a customer cancelled or not
# * Whether a customer received a discount or not
# * The number of listening sessions
# * Percent of listening history consisting of Pop
# * Percent of listening history consisting of Podcasts

# %%
# Create a dataframe ready for modeling
semi_table = audio_listening_hist.merge(session)

# %%
final_table = customers.merge(semi_table)

# %%
final_table.head()
# Out:
#    Customer ID   Customer Name                       Email Member Since  \
# 0         5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 1         5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 2         5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 3         5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 4         5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
#
#   Subscription Plan  Subscription Rate Discount? Cancellation Date  Cancelled  \
# 0       Basic (ADS)               2.99        No               NaT          0
# 1       Basic (ADS)               2.99        No               NaT          0
# 2       Basic (ADS)               2.99        No               NaT          0
# 3       Basic (ADS)               2.99        No               NaT          0
# 4       Basic (ADS)               2.99        No               NaT          0
#
#    Session ID  Audio Order  Audio ID Audio Type   ID              Name  \
# 0      100520            1       101       Song  101   Dance All Night
# 1      100520            2       102       Song  102  Unbreakable Beat
# 2      100520            3       103       Song  103  Sunset Boulevard
# 3      100520            4       104       Song  104    Glowing Hearts
# 4      100520            5       105       Song  105         Pop Rocks
#
#        Genre  Popularity Session Log In Time
# 0        Pop           1 2023-03-13 18:29:00
# 1        Pop           2 2023-03-13 18:29:00
# 2  Pop Music           5 2023-03-13 18:29:00
# 3  Pop Music          10 2023-03-13 18:29:00
# 4  Pop Music          52 2023-03-13 18:29:00

# %%
# Calculate the number of listening sessions for each customer
customer_listening = final_table.groupby("Customer ID")["Session ID"].nunique()

# %%
# Percent pop
(len(final_table[final_table.Genre == "Pop"]) / len(final_table[final_table.Genre.notna()]))* 100
# Out:
# 19.801980198019802

# %%
# Percent podcasts

# %% [markdown]
# Visualize the relationships in the modeling DataFrame using a pair plot:
# * What are some of your observations?
# * What variables might do a good job predicting customer cancellation?

# %%
sns.pairplot(final_table)

# %%
final_table.corr()
# Out:
# C:\Users\harshs\AppData\Local\Temp\ipykernel_64728\164737582.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   final_table.corr()
#                    Customer ID  Subscription Rate  Cancelled  Session ID  \
# Customer ID           1.000000           0.442400   0.434325    0.378586
# Subscription Rate     0.442400           1.000000   0.680446   -0.003440
# Cancelled             0.434325           0.680446   1.000000    0.002264
# Session ID            0.378586          -0.003440   0.002264    1.000000
# Audio Order           0.016992          -0.113903  -0.044100   -0.145404
# Audio ID              0.089991           0.195619   0.010453    0.043837
# ID                    0.089991           0.195619   0.010453    0.043837
# Popularity            0.182633          -0.129340  -0.266578    0.018842
#
#                    Audio Order  Audio ID        ID  Popularity
# Customer ID           0.016992  0.089991  0.089991    0.182633
# Subscription Rate    -0.113903  0.195619  0.195619   -0.129340
# Cancelled            -0.044100  0.010453  0.010453   -0.266578
# Session ID           -0.145404  0.043837  0.043837    0.018842
# Audio Order           1.000000 -0.239904 -0.239904    0.052303
# Audio ID             -0.239904  1.000000  1.000000   -0.051972
# ID                   -0.239904  1.000000  1.000000   -0.051972
# Popularity            0.052303 -0.051972 -0.051972    1.000000

# %%
final_table
# Out:
#      Customer ID   Customer Name                       Email Member Since  \
# 0           5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 1           5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 2           5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 3           5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 4           5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# ..           ...             ...                         ...          ...
# 500         7581      Lyric Keys       keysoflyric@email.com   2023-05-16
# 501         7581      Lyric Keys       keysoflyric@email.com   2023-05-16
# 502         7581      Lyric Keys       keysoflyric@email.com   2023-05-16
# 503         7583   Melody Singer    melodic.singer@email.com   2023-05-16
# 504         7583   Melody Singer    melodic.singer@email.com   2023-05-16
#
#     Subscription Plan  Subscription Rate Discount? Cancellation Date  \
# 0         Basic (ADS)               2.99        No               NaT
# 1         Basic (ADS)               2.99        No               NaT
# 2         Basic (ADS)               2.99        No               NaT
# 3         Basic (ADS)               2.99        No               NaT
# 4         Basic (ADS)               2.99        No               NaT
# ..                ...                ...       ...               ...
# 500  Premium (No Ads)               7.99       Yes        2023-06-03
# 501  Premium (No Ads)               7.99       Yes        2023-06-03
# 502  Premium (No Ads)               7.99       Yes        2023-06-03
# 503  Premium (No Ads)               7.99       Yes        2023-06-01
# 504  Premium (No Ads)               7.99       Yes        2023-06-01
#
#      Cancelled  Session ID  Audio Order  Audio ID Audio Type   ID  \
# 0            0      100520            1       101       Song  101
# 1            0      100520            2       102       Song  102
# 2            0      100520            3       103       Song  103
# 3            0      100520            4       104       Song  104
# 4            0      100520            5       105       Song  105
# ..         ...         ...          ...       ...        ...  ...
# 500          1      110113            4       101       Song  101
# 501          1      110113            5       103       Song  103
# 502          1      110113            6       205    Podcast  205
# 503          1      111057            1       201    Podcast  201
# 504          1      111057            2       202    Podcast  202
#
#                        Name       Genre  Popularity Session Log In Time
# 0           Dance All Night         Pop           1 2023-03-13 18:29:00
# 1          Unbreakable Beat         Pop           2 2023-03-13 18:29:00
# 2          Sunset Boulevard   Pop Music           5 2023-03-13 18:29:00
# 3            Glowing Hearts   Pop Music          10 2023-03-13 18:29:00
# 4                 Pop Rocks   Pop Music          52 2023-03-13 18:29:00
# ..                      ...         ...         ...                 ...
# 500         Dance All Night         Pop           1 2023-05-16 19:50:00
# 501        Sunset Boulevard   Pop Music           5 2023-05-16 19:50:00
# 502  Investigating Darkness  True Crime          17 2023-05-16 19:50:00
# 503          Jokes on Jokes      Comedy           2 2023-05-17 00:35:00
# 504      Laugh Out Loudcast      Comedy           8 2023-05-17 00:35:00
#
# [505 rows x 18 columns]

# %%
customers
# Out:
#     Customer ID      Customer Name                         Email Member Since  \
# 0          5001     Harmony Greene    harmonious.vibes@email.com   2023-03-13
# 1          5002          Aria Keys      melodious.aria@email.edu   2023-03-13
# 2          5004         Lyric Bell    rhythmical.lyric@email.com   2023-03-13
# 3          5267       Rock Bassett         groovy.rock@email.com   2023-03-20
# 4          5338       Rhythm Dixon     beats.by.rhythm@email.edu   2023-03-20
# 5          5404        Jazz Saxton           jazzy.sax@email.com   2023-03-20
# 6          5581         Reed Sharp         sharp.tunes@email.com   2023-03-21
# 7          5759     Carol Kingbird      songbird.carol@email.com   2023-03-22
# 8          5761        Sonata Nash      musical.sonata@email.com   2023-03-28
# 9          5763       Jazz Coleman  coleman.jazzmaster@email.com   2023-03-28
# 10         5826        Chord Hayes      harmonic.chord@email.com   2023-03-28
# 11         5827    Rhythm Franklin   rhythmic.franklin@email.edu   2023-03-28
# 12         6029     Chord Campbell   campbell.chordify@email.com   2023-03-29
# 13         6092         Benny Beat      rhythmic.benny@email.com   2023-04-01
# 14         6163       Melody Parks    park.of.melodies@email.com   2023-04-05
# 15         6229    Symphony Rhodes     rhodes.symphony@email.com   2023-04-06
# 16         6406     Beatrice Sharp   beats.by.beatrice@email.com   2023-04-08
# 17         6584         Bobby Bass   bass.master.bobby@email.edu   2023-04-09
# 18         6586     Lyric Saunders    lyrical.saunders@email.edu   2023-04-16
# 19         6588       Harmony Bass        bass.harmony@email.com   2023-04-16
# 20         6821          Reed Flat          flat.tunes@email.edu   2023-04-24
# 21         6822          Kiki Keys     kiki.keys.piano@email.com   2023-05-01
# 22         6824       Greta Groove        groovy.greta@email.com   2023-05-01
# 23         7087      Harmony Heart   heartfelt.harmony@email.com   2023-05-01
# 24         7158    Harmony Wallace     wallace.harmony@email.com   2023-05-07
# 25         7224  Melody Fitzgerald   fitzgerald.melody@email.com   2023-05-08
# 26         7401        Reed Murphy   murphy.reed.music@email.com   2023-05-08
# 27         7579      Jazz Drummond       drumming.jazz@email.com   2023-05-15
# 28         7581         Lyric Keys         keysoflyric@email.com   2023-05-16
# 29         7583      Melody Singer      melodic.singer@email.com   2023-05-16
#
#    Subscription Plan  Subscription Rate Discount? Cancellation Date  Cancelled
# 0        Basic (ADS)               2.99        No               NaT          0
# 1        Basic (ADS)               2.99        No               NaT          0
# 2        Basic (ADS)               2.99        No        2023-06-01          1
# 3        Basic (ADS)               2.99        No               NaT          0
# 4        Basic (ADS)               2.99        No               NaT          0
# 5        Basic (ADS)               2.99        No        2023-06-03          1
# 6   Premium (No Ads)               9.99        No               NaT          0
# 7   Premium (No Ads)               9.99        No        2023-06-02          1
# 8   Premium (No Ads)               9.99        No               NaT          0
# 9        Basic (ADS)               2.99        No               NaT          0
# 10       Basic (ADS)               2.99        No               NaT          0
# 11       Basic (ADS)               2.99        No               NaT          0
# 12  Premium (No Ads)               9.99        No        2023-06-02          1
# 13       Basic (ADS)               2.99        No        2023-06-01          1
# 14  Premium (No Ads)               9.99        No               NaT          0
# 15  Premium (No Ads)               9.99        No        2023-06-02          1
# 16       Basic (ADS)               2.99        No               NaT          0
# 17       Basic (ADS)               2.99        No               NaT          0
# 18       Basic (ADS)               2.99        No               NaT          0
# 19       Basic (ADS)               2.99        No        2023-06-01          1
# 20       Basic (ADS)               2.99        No               NaT          0
# 21  Premium (No Ads)               7.99       Yes               NaT          0
# 22  Premium (No Ads)               7.99       Yes        2023-06-02          1
# 23  Premium (No Ads)               7.99       Yes        2023-06-02          1
# 24       Basic (ADS)               2.99        No               NaT          0
# 25  Premium (No Ads)               7.99       Yes        2023-06-01          1
# 26  Premium (No Ads)               7.99       Yes        2023-06-01          1
# 27       Basic (ADS)               2.99        No               NaT          0
# 28  Premium (No Ads)               7.99       Yes        2023-06-03          1
# 29  Premium (No Ads)               7.99       Yes        2023-06-01          1

# %%
genres = pd.get_dummies(audio_listening_hist.Genre)
customer_genre = pd.concat([audio_listening_hist["Customer ID"], genres], axis=1)
customer_genre = customer_genre.groupby("Customer ID").sum()
genre_rate = customer_genre.merge(customers[["Customer ID", "Subscription Rate"]], how="left", on="Customer ID")

# %%
customers["Discount"] = np.where(customers["Discount?"] == "No", 0 , 1)

# %%
genre_rate_discount = genre_rate.merge(customers[["Customer ID", "Discount"]], how="left")
# Out:
#     Customer ID  Comedy  Country  Hip Hop  Jazz  Pop  Pop Music  True Crime  \
# 0          5001       0        0       26     0   12         22           0
# 1          5002       0       22        0     0    0          0           0
# 2          5004       0        0        0     0    3          6           0
# 3          5267       0        0       22     0    7         16           0
# 4          5338       0       18        0     0    0          0           0
# 5          5404       0        0        0     0    2          6           0
# 6          5581       0        0        0     0    0          0           5
# 7          5759       0        0        0     0    5         10           0
# 8          5761       0        0        0     0    0          0           5
# 9          5763       0        0       11     0    8         12           0
# 10         5826       0       17        0     0    0          0           0
# 11         5827       0        0        0     0    3          4           0
# 12         6029       0        0        0     0    4          8           0
# 13         6092       4        0        3     0    2          1           0
# 14         6163       0        0        0     0    0          0           4
# 15         6229       0        0        0     0    3         10           0
# 16         6406       4        0        2     0    2          1           0
# 17         6584       0        4        6     4    6          7           0
# 18         6586       0        4        4     4    4          6           0
# 19         6588       3        0        3     0    2          2           0
# 20         6821       0        3        5     3    4          6           0
# 21         6822       0        0        0    15    0          0           0
# 22         6824       0        0        0     0   12         19           0
# 23         7087       3        0        3     0    2          3           0
# 24         7158       0        0        0    13    0          0           0
# 25         7224       0        0        0     0   12         17           0
# 26         7401       3        0        3     0    2          3           0
# 27         7579       0        0        0     9    0          0           0
# 28         7581       0        0        0     0    5          8           1
# 29         7583       2        0        0     0    0          0           0
#
#     Subscription Rate  Discount
# 0                2.99         0
# 1                2.99         0
# 2                2.99         0
# 3                2.99         0
# 4                2.99         0
# 5                2.99         0
# 6                9.99         0
# 7                9.99         0
# 8                9.99         0
# 9                2.99         0
# 10               2.99         0
# 11               2.99         0
# 12               9.99         0
# 13               2.99         0
# 14               9.99         0
# 15               9.99         0
# 16               2.99         0
# 17               2.99         0
# 18               2.99         0
# 19               2.99         0
# 20               2.99         0
# 21               7.99         1
# 22               7.99         1
# 23               7.99         1
# 24               2.99         0
# 25               7.99         1
# 26               7.99         1
# 27               2.99         0
# 28               7.99         1
# 29               7.99         1

# %%
final_table
# Out:
#      Customer ID   Customer Name                       Email Member Since  \
# 0           5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 1           5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 2           5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 3           5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# 4           5001  Harmony Greene  harmonious.vibes@email.com   2023-03-13
# ..           ...             ...                         ...          ...
# 500         7581      Lyric Keys       keysoflyric@email.com   2023-05-16
# 501         7581      Lyric Keys       keysoflyric@email.com   2023-05-16
# 502         7581      Lyric Keys       keysoflyric@email.com   2023-05-16
# 503         7583   Melody Singer    melodic.singer@email.com   2023-05-16
# 504         7583   Melody Singer    melodic.singer@email.com   2023-05-16
#
#     Subscription Plan  Subscription Rate Discount? Cancellation Date  \
# 0         Basic (ADS)               2.99        No               NaT
# 1         Basic (ADS)               2.99        No               NaT
# 2         Basic (ADS)               2.99        No               NaT
# 3         Basic (ADS)               2.99        No               NaT
# 4         Basic (ADS)               2.99        No               NaT
# ..                ...                ...       ...               ...
# 500  Premium (No Ads)               7.99       Yes        2023-06-03
# 501  Premium (No Ads)               7.99       Yes        2023-06-03
# 502  Premium (No Ads)               7.99       Yes        2023-06-03
# 503  Premium (No Ads)               7.99       Yes        2023-06-01
# 504  Premium (No Ads)               7.99       Yes        2023-06-01
#
#      Cancelled  Session ID  Audio Order  Audio ID Audio Type   ID  \
# 0            0      100520            1       101       Song  101
# 1            0      100520            2       102       Song  102
# 2            0      100520            3       103       Song  103
# 3            0      100520            4       104       Song  104
# 4            0      100520            5       105       Song  105
# ..         ...         ...          ...       ...        ...  ...
# 500          1      110113            4       101       Song  101
# 501          1      110113            5       103       Song  103
# 502          1      110113            6       205    Podcast  205
# 503          1      111057            1       201    Podcast  201
# 504          1      111057            2       202    Podcast  202
#
#                        Name       Genre  Popularity Session Log In Time
# 0           Dance All Night         Pop           1 2023-03-13 18:29:00
# 1          Unbreakable Beat         Pop           2 2023-03-13 18:29:00
# 2          Sunset Boulevard   Pop Music           5 2023-03-13 18:29:00
# 3            Glowing Hearts   Pop Music          10 2023-03-13 18:29:00
# 4                 Pop Rocks   Pop Music          52 2023-03-13 18:29:00
# ..                      ...         ...         ...                 ...
# 500         Dance All Night         Pop           1 2023-05-16 19:50:00
# 501        Sunset Boulevard   Pop Music           5 2023-05-16 19:50:00
# 502  Investigating Darkness  True Crime          17 2023-05-16 19:50:00
# 503          Jokes on Jokes      Comedy           2 2023-05-17 00:35:00
# 504      Laugh Out Loudcast      Comedy           8 2023-05-17 00:35:00
#
# [505 rows x 18 columns]
